# %% [markdown]
# # Project : Human Activity Recognition System
#
# ### Notebook 2:

# %% [markdown]
# ### This notebook includes fitting the pre-processed data from the Notebook01, applying different models to identify the best performing model and the discussion and analysis of the models.

# %%
# Importing necessary libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
#Importing warnings to ingore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Loading the pre-processed data from the Notebook01.

# %%
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')
y_test = pd.read_csv('y_test.csv')

# %% [markdown]
# ## Fitting a Logistic Regression model

# %%
logistic_reg = LogisticRegression(random_state=42)
logistic_reg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Make predictions
y_pred_logistic = logistic_reg.predict(X_test)

# %% [markdown]
# ### Measuring the performance of Logistic Regression model

# %%
# Accuracy
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)

# Confusion Matrix
conf_matrix_logistic = confusion_matrix(y_test, y_pred_logistic)

# Classification Report
class_report_logistic = classification_report(y_test, y_pred_logistic)

print(f'Logistic Regression Accuracy: {accuracy_logistic}')
print(f'Logistic Regression Confusion Matrix: \n{conf_matrix_logistic}')
print(f'Logistic Regression Classification Report: \n{class_report_logistic}')
# Out:
# Logistic Regression Accuracy: 0.9802588996763754
# Logistic Regression Confusion Matrix:
# [[526   0   3   0   0   0]
#  [  6 444   1   0   0   0]
#  [  1   0 424   0   0   0]
#  [  0   0   0 529  26   0]
#  [  0   0   0  24 543   0]
#  [  0   0   0   0   0 563]]
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99       529
#            2       1.00      0.98      0.99       451
#            3       0.99      1.00      0.99       425
#            4       0.96      0.95      0.95       555
#            5       0.95      0.96      0.96       567
#            6       1.00      1.00      1.00       563
#
#     accuracy                           0.98      3090
#    macro avg       0.98      0.98      0.98      3090
# weighted avg       0.98      0.98      0.98      3090

# %% [markdown]
# ### Applying Random Search for Logistic Regression

# %%
# Create the Logistic Regression model
logistic_reg = LogisticRegression()

# Define the hyperparameter grid
param_dist = {
    'C': np.logspace(-4, 4, 20),  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],     # Regularization penalty type
    'solver': ['liblinear', 'newton-cg', 'lbfgs', 'saga']  # Optimization algorithm
}

# Create the Randomized SearchCV object
random_search = RandomizedSearchCV(
    logistic_reg, param_distributions=param_dist, n_iter=10, cv=5, n_jobs=-1, random_state=42, verbose=1
)

# Fit the randomized search to the data
random_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_logistic_reg = random_search.best_estimator_

# Make predictions using the best model
y_pred_logistic_random = best_logistic_reg.predict(X_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ### Applying Grid Search for Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV

# Create the Logistic Regression model
logistic_reg = LogisticRegression()

# Define the hyperparameter grid
param_grid = {
    'C': np.logspace(-4, 4, 20),  # Inverse of regularization strength
    'penalty': ['l1', 'l2'],     # Regularization penalty type
    'solver': ['liblinear', 'newton-cg', 'lbfgs', 'saga']  # Optimization algorithm
}

# Create the Grid SearchCV object
grid_search = GridSearchCV(
    logistic_reg, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1
)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Get the best model
best_logistic_reg = grid_search.best_estimator_

# Make predictions using the best model
y_pred_logistic_grid = best_logistic_reg.predict(X_test)
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ## Fitting a Linear Kernel model

# %%
# Initialize the model with a linear kernel
clf_linear = SVC(kernel='linear')
# Train the model
clf_linear.fit(X_train, y_train)
# Make predictions
y_pred_linear = clf_linear.predict(X_test)

# %% [markdown]
# ### Measuring the performance of Linear Kernel model

# %%
# Accuracy
accuracy_linear = accuracy_score(y_test, y_pred_linear)
# Confusion Matrix
conf_matrix_linear = confusion_matrix(y_test, y_pred_linear)
# Classification Report
class_report_linear = classification_report(y_test, y_pred_linear)

print(f'Linear Kernel Accuracy: {accuracy_linear}')
print(f'Linear Kernel Confusion Matrix: \n{conf_matrix_linear}')
print(f'Linear Kernel Classification Report: \n{class_report_linear}')
# Out:
# Linear Kernel Accuracy: 0.9786407766990292
# Linear Kernel Confusion Matrix:
# [[528   0   1   0   0   0]
#  [  4 445   2   0   0   0]
#  [  4   2 419   0   0   0]
#  [  0   0   0 529  26   0]
#  [  0   0   0  27 540   0]
#  [  0   0   0   0   0 563]]
# Linear Kernel Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       529
#            2       1.00      0.99      0.99       451
#            3       0.99      0.99      0.99       425
#            4       0.95      0.95      0.95       555
#            5       0.95      0.95      0.95       567
#            6       1.00      1.00      1.00       563
#
#     accuracy                           0.98      3090
#    macro avg       0.98      0.98      0.98      3090
# weighted avg       0.98      0.98      0.98      3090

# %% [markdown]
# ## Fitting a Non-Linear Kernel (RBF) model

# %%
# Initialize the model with an RBF kernel
clf_rbf = SVC(kernel='rbf')
# Train the model
clf_rbf.fit(X_train, y_train)
# Make predictions
y_pred_rbf = clf_rbf.predict(X_test)

# %% [markdown]
# ### Measuring the performance of Non-Linear Kernel model

# %%
# Accuracy
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)
# Confusion Matrix
conf_matrix_rbf = confusion_matrix(y_test, y_pred_rbf)
# Classification Report
class_report_rbf = classification_report(y_test, y_pred_rbf)

print(f'RBF Kernel Accuracy: {accuracy_rbf}')
print(f'RBF Kernel Confusion Matrix: \n{conf_matrix_rbf}')
print(f'RBF Kernel Classification Report: \n{class_report_rbf}')
# Out:
# RBF Kernel Accuracy: 0.9744336569579288
# RBF Kernel Confusion Matrix:
# [[526   0   3   0   0   0]
#  [  1 445   5   0   0   0]
#  [  0   1 424   0   0   0]
#  [  0   0   0 516  38   1]
#  [  0   0   0  29 538   0]
#  [  0   0   1   0   0 562]]
# RBF Kernel Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      0.99      1.00       529
#            2       1.00      0.99      0.99       451
#            3       0.98      1.00      0.99       425
#            4       0.95      0.93      0.94       555
#            5       0.93      0.95      0.94       567
#            6       1.00      1.00      1.00       563
#
#     accuracy                           0.97      3090
#    macro avg       0.98      0.98      0.98      3090
# weighted avg       0.97      0.97      0.97      3090

# %% [markdown]
# ### Applying Randomized Search for SVM

# %%
# Create the SVM model
svm_model = SVC()

# Define the hyperparameter grid
param_dist = {
    'C': np.logspace(-3, 3, 7),          # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly'],  # Kernel type
    'gamma': np.logspace(-3, 3, 7)       # Kernel coefficient for 'rbf' and 'poly'
}

# Create the Randomized SearchCV object
random_search_svm = RandomizedSearchCV(
    svm_model, param_distributions=param_dist, n_iter=10, cv=5, n_jobs=-1, random_state=42, verbose=1
)

# Fit the randomized search to the data
random_search_svm.fit(X_train, y_train)

# Get the best hyperparameters
best_params_svm = random_search_svm.best_params_
print("Best Hyperparameters (SVM):", best_params_svm)

# Get the best model
best_svm_model = random_search_svm.best_estimator_

# Make predictions using the best SVM model
y_pred_svm_random = best_svm_model.predict(X_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ### Applying Grid Search for SVM

# %%
# Create the SVM model
svm_model = SVC()

# Define the hyperparameter grid
param_grid = {
    'C': np.logspace(-3, 3, 7),          # Regularization parameter
    'kernel': ['linear', 'rbf', 'poly'],  # Kernel type
    'gamma': np.logspace(-3, 3, 7)       # Kernel coefficient for 'rbf' and 'poly'
}

# Create the Grid SearchCV object
grid_search_svm = GridSearchCV(
    svm_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1
)

# Fit the grid search to the data
grid_search_svm.fit(X_train, y_train)

# Get the best hyperparameters
best_params_svm = grid_search_svm.best_params_
print("Best Hyperparameters (SVM):", best_params_svm)

# Get the best model
best_svm_model = grid_search_svm.best_estimator_

# Make predictions using the best SVM model
y_pred_svm_grid = best_svm_model.predict(X_test)
# Out:
# Fitting 5 folds for each of 147 candidates, totalling 735 fits
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/sunilinus/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# ## Fitting a Decision-Tree model

# %%
# Initialize and train the Decision Tree model
clf = DecisionTreeClassifier(random_state=42)
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred_decision = clf.predict(X_test)

# %% [markdown]
# ### Measuring the performance of Decision-Tree model

# %%
# Accuracy
accuracy_linear = accuracy_score(y_test, y_pred_decision)
# Confusion Matrix
conf_matrix_decision = confusion_matrix(y_test, y_pred_decision)
# Classification Report
class_report_decision = classification_report(y_test, y_pred_decision)

print(f'Decision Tree Accuracy: {accuracy_linear}')
print(f'Decision Tree Confusion Matrix: \n{conf_matrix_linear}')
print(f'Decision Tree Classification Report: \n{class_report_linear}')
# Out:
# Decision Tree Accuracy: 0.9262135922330097
# Decision Tree Confusion Matrix:
# [[528   0   1   0   0   0]
#  [  4 445   2   0   0   0]
#  [  4   2 419   0   0   0]
#  [  0   0   0 529  26   0]
#  [  0   0   0  27 540   0]
#  [  0   0   0   0   0 563]]
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      0.99       529
#            2       1.00      0.99      0.99       451
#            3       0.99      0.99      0.99       425
#            4       0.95      0.95      0.95       555
#            5       0.95      0.95      0.95       567
#            6       1.00      1.00      1.00       563
#
#     accuracy                           0.98      3090
#    macro avg       0.98      0.98      0.98      3090
# weighted avg       0.98      0.98      0.98      3090

# %% [markdown]
# ### Applying Random Search for Decision Tree

# %%
# Create the Decision Tree model
decision_tree_model = DecisionTreeClassifier(random_state=42)

# Define the hyperparameter grid
param_dist = {
    'criterion': ['gini', 'entropy'],        # Criterion for split
    'max_depth': np.arange(1, 11),          # Maximum depth of the tree
    'min_samples_split': np.arange(2, 11),  # Minimum samples required to split an internal node
    'min_samples_leaf': np.arange(1, 11)    # Minimum samples required to be at a leaf node
}

# Create the Randomized SearchCV object
random_search_decision_tree = RandomizedSearchCV(
    decision_tree_model, param_distributions=param_dist, n_iter=10, cv=5, n_jobs=-1, random_state=42, verbose=1
)

# Fit the randomized search to the data
random_search_decision_tree.fit(X_train, y_train)

# Get the best hyperparameters
best_params_decision_tree = random_search_decision_tree.best_params_
print("Best Hyperparameters (Decision Tree):", best_params_decision_tree)

# Get the best model
best_decision_tree_model = random_search_decision_tree.best_estimator_

# Make predictions using the best Decision Tree model
y_pred_decision_tree_random = best_decision_tree_model.predict(X_test)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Hyperparameters (Decision Tree): {'min_samples_split': 2, 'min_samples_leaf': 3, 'max_depth': 9, 'criterion': 'entropy'}

# %% [markdown]
# ### Applying Grid Search for Decision Tree

# %%
# Create the Decision Tree model
decision_tree_model = DecisionTreeClassifier(random_state=42)

# Define the hyperparameter grid
param_grid = {
    'criterion': ['gini', 'entropy'],        # Criterion for split
    'max_depth': np.arange(1, 11),          # Maximum depth of the tree
    'min_samples_split': np.arange(2, 11),  # Minimum samples required to split an internal node
    'min_samples_leaf': np.arange(1, 11)    # Minimum samples required to be at a leaf node
}

# Create the Grid SearchCV object
grid_search_decision_tree = GridSearchCV(
    decision_tree_model, param_grid=param_grid, cv=5, n_jobs=-1, verbose=1
)

# Fit the grid search to the data
grid_search_decision_tree.fit(X_train, y_train)

# Get the best hyperparameters
best_params_decision_tree = grid_search_decision_tree.best_params_
print("Best Hyperparameters (Decision Tree):", best_params_decision_tree)

# Get the best model
best_decision_tree_model = grid_search_decision_tree.best_estimator_

# Make predictions using the best Decision Tree model
y_pred_decision_tree_grid = best_decision_tree_model.predict(X_test)
# Out:
# Fitting 5 folds for each of 1800 candidates, totalling 9000 fits
# Best Hyperparameters (Decision Tree): {'criterion': 'entropy', 'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 4}

# %% [markdown]
# #### Now that I have derived the performance of the models using different metrics, I'll analyse the results and conclude the analysis.

# %% [markdown]
# ## Analysis:
#
# The primary goal of this analysis is to compare the performance of different machine learning models in predicting human activities based on sensor data.
#
# ### Summary of the performance parameters for each of the models individually:
#
# ##### Logistic Regression Model:
#
# Accuracy: 0.9803
#
# Precision, Recall, and F1-Score: Precision, Recall, and F1-Score: For all activity classes (1-6), this model displays impressive precision, recall, and F1-scores, demonstrating that it does a great job of identifying these activities. For instance, it has an F1-score of 0.99 for the majority of classes, demonstrating the harmony between recall and precision.
#
# Confusion Matrix: Very few incorrect classifications are shown by the confusion matrix for logistic regression, with most diagonal elements displaying accurate predictions. This shows that it does a great job of differentiating between various human activities.
#
# Random Search: The best hyperparameters for the Logistic Regression model found through random search were:
#
# - Solver: 'liblinear'
# - Penalty: 'l2'
# - Regularization Strength (C): 11.29
#
# Grid Search: The best hyperparameters for the Logistic Regression model found through grid search were:
#
# - Regularization Strength (C): 0.62
# - Penalty: 'l1'
# - Solver: 'liblinear'
#
# ##### Linear Kernel SVM Model:
#
# Accuracy: 0.9786
#
# Precision, Recall, and F1-Score: The Linear Kernel SVM offers great precision, recall, and F1-scores for all activity classes (1-6), similar to Logistic Regression. It consistently performs well in all classes.
#
# Confusion Matrix: The confusion matrix shows that this model is also quite good at categorizing human activities, with very few misclassifications.
#
# Random Search: The best hyperparameters for the Linear Kernel SVM model found through random search were:
#
# - Kernel: 'linear'
# - Regularization Strength (C): 100.0
#
# Grid Search: The best hyperparameters for the Linear Kernel SVM model found through grid search were:
#
# - Regularization Strength (C): 100.0
# - Kernel: 'linear'
#
# ##### Non-Linear Kernel (RBF) SVM Model:
#
# Accuracy: 0.9744
#
# Precision, Recall, and F1-Score: For all activity classes, this model retains high precision, recall, and F1-scores, however there are a few more misclassifications than with the linear models.
#
# Confusion Matrix: In comparison to Logistic Regression and Linear SVM, the confusion matrix displays a somewhat higher number of misclassifications, indicating that it may not be as accurate at differentiating between activities.
#
# Random Search: The best hyperparameters for the RBF Kernel SVM model found through random search were:
#
# - Kernel: 'poly'
# - Regularization Strength (C): 1000.0
# - Kernel Coefficient (Gamma): 1000.0
#
# Grid Search: The best hyperparameters for the RBF Kernel SVM model found through grid search were:
#
# - Regularization Strength (C): 100.0
# - Kernel: 'rbf'
# - Kernel Coefficient (Gamma): 0.001
#
# ##### Decision Tree Model:
#
# Accuracy: 0.9262
#
# Precision, Recall, and F1-Score: Performance of the Decision Tree model lags behind the other models slightly, particularly in terms of precision, recall, and F1-scores for specific classes. As a result, it might not be as useful for categorizing some activities.
#
# Confusion Matrix: Comparing the confusion matrix to the SVM and Logistic Regression models, it shows that there are higher misclassifications. Although some of the pieces are diagonal, there are also more off-diagonal elements.
#
# Random Search: The best hyperparameters for the Decision Tree model found through random search were:
#
# - Criterion: 'entropy'
# - Maximum Depth: 9
# - Minimum Samples Split: 2
# - Minimum Samples Leaf: 3
#
# Grid Search: The best hyperparameters for the Decision Tree model found through grid search were:
#
# - Criterion: 'entropy'
# - Maximum Depth: 9
# - Minimum Samples Split: 4
# - Minimum Samples Leaf: 1
#
# #### Overall Comparision:
#
# - For all activity classes, the Logistic Regression model achieves the maximum accuracy and upholds excellent precision, recall, and F1-scores. The best overall performance is delivered.
#
# - In terms of performance, Logistic Regression is closely followed by Linear Kernel SVM. For all classes, it demonstrates great accuracy, exceptional precision, and recall.
#
# - Although it still performs well, the RBF Kernel SVM exhibits somewhat more misclassifications than the linear models. However, it's a reliable option.
#
# - The Decision Tree model may not be the ideal option for this particular classification problem given its lower overall accuracy and F1-scores for some classes.
#
# ### Best-Performing Model:
#
# To identify the best-performing model, I am comparing the accuracy scores of each model. Accuracy is a common and intuitive metric to assess how well the models classify activities correctly in a multiclass classification problem. Moreover, Accuracy is a good choice here because it provides an overall measure of how well the models are performing in classifying the activities. It's easy to understand and interpret.
#
# The following accuracy scores are derived:
#
# - Logistic Regression Accuracy: 0.9802
#
# - Linear Kernel SVM Accuracy: 0.9786
#
# - RBF Kernel SVM Accuracy: 0.9744
#
# - Decision Tree Accuracy: 0.9262
#
# The Logistic Regression model, which has an accuracy of 0.9803, is the top-performing model out of those put to the test. For all activity classes (1-6), this model has high precision, recall, and F1-scores and has only a few instances of misclassifications, as seen in the confusion matrix.
#
# With an accuracy of 0.9786, which is very close to the Logistic Regression model, the Linear Kernel SVM is the second-best performing model. Additionally, it gives minimum misclassifications, good recall, precision, and F1-scores for all classes.
#
# With an accuracy of 0.9744, the RBF Kernel SVM performs well, but it has a few more misclassifications than the linear models. For all courses, it still offers good precision and recall.
#
# In comparison to the other models, the Decision Tree model exhibits more misclassifications and has a good accuracy of 0.9262, but it also has slightly lower precision, recall, and F1-scores for various classes.
#
# In conclusion, based on the available data and features, the Logistic Regression model seems to be the best option for this classification problem. It is a reliable option for predicting human activities from sensor data since it obtains the best accuracy and upholds high precision and recall for all classes.
